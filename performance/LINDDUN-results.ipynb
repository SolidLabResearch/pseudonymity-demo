# %% [markdown]
# # LINDDUN

# %% [markdown]
# In the following, we discuss the main results of applying the LINDDUN methodology
# [https://linddun.org/pro/](https://linddun.org/pro/) to conduct a privacy threat analysis on both solutions.
#
# LINDDUN categorizes threats into seven threat types:
# - **Linking**: Associating data items or user actions to learn more about an individual or group.
# - **Identifying**: Learning the identity of an individual through leaks, deduction, or inference.
# - **Non-repudiation**: Being able to attribute a claim to an individual.
# - **Detecting**: Deducing the involvement of an individual through observation.
# - **Data disclosure**: Excessively collecting, storing, processing, or sharing personal data.
# - **Unawareness & Unintervenability**: Insufficiently informing, involving, or empowering individuals in the processing of their personal data.
# - **Non-compliance**: Deviating from security and data management best practices, standards, and legislation.
#
# In our analysis, we assume that the pseudonymizer:
# 1. Sufficiently informs its users about how their personal data is being processed; and
# 2. Is compliant with GDPR legislation.
#
# Therefore, we consider both solutions to yield no threats to the types **Unawareness & Unintervenability** and **Non-Compliance**.

# %%
import pandas as pd
import os

# %%
fpath = './LINDDUN-analysis.xlsx'
xlf = pd.io.excel.ExcelFile(fpath)
print(xlf.sheet_names)
# Out:
# ['Flow', 'LINDDUN-GO-CARDS', 'LINDDUN-GO-HOTSPOTS', 'ANALYSIS-GO-v1', 'ANALYSIS-GO-v2', 'ANALYSIS-PRO', 'LINDDUN-Threat-trees']

# %%
sheet_name = 'ANALYSIS-PRO'
df = pd.read_excel(xlf, sheet_name=sheet_name)
df.Phase.value_counts(dropna=False)
# Filter phase: Diploma verification
df = df[df.Phase == 'Diploma verification'].drop('Phase',axis=1)
df.dropna(axis=0, how='all', inplace=True)
print(df.shape)
df
# Out:
# (52, 11)
#         SOLUTION  S_ID       DF_ID  D_ID      T_ID  \
# 0    webid-webid  P1.2           -     -     L.1.1
# 1   webid-didkey  P1.2           -     -     L.1.1
# 2    webid-webid  P1.2           -     -     L.1.2
# 3   webid-didkey  P1.2           -     -     L.1.2
# 4    webid-webid  P1.2           -     -     I.1.1
# 5    webid-webid     -           -     -     I.1.2
# 6   webid-didkey     -           -     -     I.1.1
# 7   webid-didkey     -           -     -     I.1.2
# 8    webid-webid     -           -     -   I.2.1.1
# 9   webid-didkey     -           -     -   I.2.1.1
# 10   webid-webid     -           -     -   I.2.1.2
# 11  webid-didkey     -           -     -   I.2.1.2
# 12   webid-webid     -           -     -     I.2.2
# 13  webid-didkey     -           -     -     I.2.2
# 14   webid-webid     -           -     -     I.2.3
# 15  webid-didkey     -           -     -     I.2.3
# 16   webid-webid  P1.2  DF-P1.1-E2    E2      Nr.1
# 17  webid-didkey  P1.2  DF-P1.1-E2    E2      Nr.1
# 18   webid-webid  P1.2  DF-P1.2-E2    E2       D.1
# 19   webid-webid    P1           -  P1.2       D.2
# 20   webid-webid  P1.2  DF-P1.2-E2    E2       D.3
# 21  webid-didkey  P1.2  DF-P1.2-E2    E2       D.1
# 22  webid-didkey  P1.2           -     -       D.2
# 23  webid-didkey  P1.2           -     -       D.3
# 24   webid-webid  P1.1           -     -    DD.1.1
# 25  webid-didkey  P1.1           -     -    DD.1.1
# 26   webid-webid  P1.1           -     -    DD.1.2
# 27  webid-didkey  P1.1           -     -    DD.1.2
# 28   webid-webid  P1.1           -     -    DD.1.3
# 29  webid-didkey  P1.1           -     -    DD.1.3
# 30   webid-webid     -           -     -    DD.2.1
# 31  webid-didkey     -           -     -    DD.2.1
# 32   webid-webid     -           -     -    DD.2.2
# 33  webid-didkey     -           -     -    DD.2.2
# 34   webid-webid     -           -     -    DD.2.3
# 35  webid-didkey     -           -     -    DD.2.3
# 36   webid-webid  P1.1           -     -    DD.3.1
# 37  webid-didkey  P1.1           -     -    DD.3.1
# 38   webid-webid    E2           -     -    DD.3.1
# 39  webid-didkey    E2           -     -    DD.3.1
# 40   webid-webid  P1.1           -     -    DD.3.2
# 41  webid-didkey  P1.1           -     -    DD.3.2
# 43   webid-webid    E2           -     -    DD.3.2
# 44  webid-didkey    E2           -     -    DD.3.2
# 46   webid-webid  P1.2           -     -    DD.3.3
# 47  webid-didkey  P1.2           -     -    DD.3.3
# 49   webid-webid  P1.2           -     -    DD.3.4
# 50  webid-didkey  P1.2           -     -    DD.3.4
# 52   webid-webid     -           -     -  DD.4.1.1
# 53  webid-didkey     -           -     -  DD.4.1.1
# 55   webid-webid     -           -     -  DD.4.1.2
# 56  webid-didkey     -           -     -  DD.4.1.2
#
#                                              Analysis Source Destination  \
# 0   P1.2 leases pseudonymous WebIDs.\nHowever, the...    NaN         NaN
# 1   Key DIDs consist of the scheme-identifier (i.e...    NaN         NaN
# 2   Attributes disclosed in the diploma verificati...    NaN         NaN
# 3   Attributes disclosed in the diploma verificati...    NaN         NaN
# 4   The system processes diploma data, and contain...    NaN         NaN
# 5          No additional metadata is being processed.    NaN         NaN
# 6   The system processes diploma data, and contain...    NaN         NaN
# 7          No additional metadata is being processed.    NaN         NaN
# 8   The pseudonymizer allows identifying informati...    NaN         NaN
# 9   The pseudonymizer allows identifying informati...    NaN         NaN
# 10  The considered use cases assumes the recruiter...    NaN         NaN
# 11  The considered use cases assumes the recruiter...    NaN         NaN
# 12  The considered use cases assumes the recruiter...    NaN         NaN
# 13  The considered use cases assumes the recruiter...    NaN         NaN
# 14  Although a new pseudonymous WebID is being use...    NaN         NaN
# 15  A new pseudonymous DID:Key is used for every j...    NaN         NaN
# 16  A credential is cryptographically tied to the ...    NaN         NaN
# 17  A credential is cryptographically tied to the ...    NaN         NaN
# 18  If an adversary can observe requests from E2. ...   TODO           /
# 19  Creation of a new pseudonym triggers a request...   TODO           /
# 20  E2 Recruiter can resolve the pseudonymous WebI...   TODO           /
# 21  The non-existence of this data flow prevents t...    NaN         NaN
# 22  The non-existence of P1.2 IDP Pseudo mitigates...    NaN         NaN
# 23  The non-existence of P1.2 IDP Pseudo mitigates...    NaN         NaN
# 24  The pseudomizer supports the principle of data...    NaN         NaN
# 25  The pseudomizer supports the principle of data...    NaN         NaN
# 26  The pseudomizer supports the principle of data...    NaN         NaN
# 27  The pseudomizer supports the principle of data...    NaN         NaN
# 28  The pseudomizer applies the principle of data ...    NaN         NaN
# 29  The pseudomizer applies the principle of data ...    NaN         NaN
# 30  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 31  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 32  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 33  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 34  The pseudomizer does not process any personal ...    NaN         NaN
# 35  The pseudomizer does not process any personal ...    NaN         NaN
# 36  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 37  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 38  We assume E2. Recruiter to be a semi-honest ac...    NaN         NaN
# 39  We assume E2. Recruiter to be a semi-honest ac...    NaN         NaN
# 40  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 41  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 43  We assume E2. Recruiter to be a semi-honest ac...    NaN         NaN
# 44  We assume E2. Recruiter to be a semi-honest ac...    NaN         NaN
# 46  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 47  The non-existence of P1.2 IDP Pseudo naturally...    NaN         NaN
# 49  We assume that the pseudomizer strictly acts i...    NaN         NaN
# 50  The non-existence of P1.2 IDP Pseudo naturally...    NaN         NaN
# 52  There are no more parties involved other than ...    NaN         NaN
# 53  There are no more parties involved other than ...    NaN         NaN
# 55  There are no more parties involved other than ...    NaN         NaN
# 56  There are no more parties involved other than ...    NaN         NaN
#
#     Threat risk?  Mitigation  \
# 0            1.0         NaN
# 1            0.0         NaN
# 2            0.0         NaN
# 3            0.0         NaN
# 4            1.0         NaN
# 5            0.0         NaN
# 6            1.0         NaN
# 7            0.0         NaN
# 8            0.0         NaN
# 9            0.0         NaN
# 10           0.0         NaN
# 11           0.0         NaN
# 12           1.0         NaN
# 13           1.0         NaN
# 14           1.0         NaN
# 15           0.0         NaN
# 16           1.0         NaN
# 17           1.0         NaN
# 18           1.0         NaN
# 19           1.0         NaN
# 20           1.0         NaN
# 21           0.0         NaN
# 22           0.0         NaN
# 23           0.0         NaN
# 24           0.0         NaN
# 25           0.0         NaN
# 26           0.0         NaN
# 27           0.0         NaN
# 28           0.0         NaN
# 29           0.0         NaN
# 30           0.0         NaN
# 31           0.0         NaN
# 32           0.0         NaN
# 33           0.0         NaN
# 34           0.0         NaN
# 35           0.0         NaN
# 36           0.0         NaN
# 37           0.0         NaN
# 38           1.0         NaN
# 39           0.0         NaN
# 40           0.0         NaN
# 41           0.0         NaN
# 43           0.0         NaN
# 44           0.0         NaN
# 46           1.0         NaN
# 47           0.0         NaN
# 49           0.0         NaN
# 50           0.0         NaN
# 52           0.0         NaN
# 53           0.0         NaN
# 55           0.0         NaN
# 56           0.0         NaN
#
#                                                Impact
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 43                                                NaN
# 44                                                NaN
# 46  Being able to detect the existence of certain ...
# 47                                                NaN
# 49                                                NaN
# 50                                                NaN
# 52                                                NaN
# 53                                                NaN
# 55                                                NaN
# 56                                                NaN

# %%
df.groupby(['SOLUTION']).size()
# Out:
# SOLUTION
# webid-didkey    26
# webid-webid     26
# dtype: int64

# %%
df.groupby(['SOLUTION'])['Threat risk?'].sum()
# Out:
# SOLUTION
# webid-didkey     3.0
# webid-webid     10.0
# Name: Threat risk?, dtype: float64

# %% [markdown]
# Threats can be considered from 3 different perspectives of the triple $(i, e_{i,j}, j)$. \
# Where $i$ and $j$ represent the source and destination entities, and $e_{i,j}$ the edge between $i$ and $j$.

# %%
g = df.groupby(['SOLUTION','T_ID',])
# Count: represents the nr of threat evaluations for a particular threat.
# Sum: the number of evaluations of which a threat was identified.
A = g['Threat risk?'].agg(['count','sum']).astype(int)
#A

# %%
# B 
B = A.unstack('SOLUTION')
# Assert that there's the same number of threat evaluations per solution
assert (B['count'].diff(axis=1).iloc(axis=1)[-1] == 0).all()
print('B:')
display(B)
# If so, we can focus on the nr. of threats per solution
# C
print('C:')
C = B['sum'] 
# Let's only consider threats for which a solution was marked.
C = C[C.sum(axis=1) > 0]
C
# Out:
# B:
#                 count                      sum
# SOLUTION webid-didkey webid-webid webid-didkey webid-webid
# T_ID
# D.1                 1           1            0           1
# D.2                 1           1            0           1
# D.3                 1           1            0           1
# DD.1.1              1           1            0           0
# DD.1.2              1           1            0           0
# DD.1.3              1           1            0           0
# DD.2.1              1           1            0           0
# DD.2.2              1           1            0           0
# DD.2.3              1           1            0           0
# DD.3.1              2           2            0           1
# DD.3.2              2           2            0           0
# DD.3.3              1           1            0           1
# DD.3.4              1           1            0           0
# DD.4.1.1            1           1            0           0
# DD.4.1.2            1           1            0           0
# I.1.1               1           1            1           1
# I.1.2               1           1            0           0
# I.2.1.1             1           1            0           0
# I.2.1.2             1           1            0           0
# I.2.2               1           1            1           1
# I.2.3               1           1            0           1
# L.1.1               1           1            0           1
# L.1.2               1           1            0           0
# Nr.1                1           1            1           1
# C:
# SOLUTION  webid-didkey  webid-webid
# T_ID
# D.1                  0            1
# D.2                  0            1
# D.3                  0            1
# DD.3.1               0            1
# DD.3.3               0            1
# I.1.1                1            1
# I.2.2                1            1
# I.2.3                0            1
# L.1.1                0            1
# Nr.1                 1            1

# %%
nr_threat_ids = C.index.unique().size
print('Nr. of threats: ', nr_threat_ids)

nr_threats_per_solution = C.sum()
print('\nNr. of identified threats per solution')
print(nr_threats_per_solution)
# Out:
# Nr. of threats:  10
#
# Nr. of identified threats per solution
# SOLUTION
# webid-didkey     3
# webid-webid     10
# dtype: int64

# %%
s1, s2 = df.SOLUTION.unique().astype(list).tolist()
print(f's1: {s1}, s2: {s2}')
# Out:
# s1: webid-webid, s2: webid-didkey

# %%
# D
D_d = "Where both solutions pose a threat."
D = C[C == 1].dropna().astype(int)
print(D_d)
D
# Out:
# Where both solutions pose a threat.
# SOLUTION  webid-didkey  webid-webid
# T_ID
# I.1.1                1            1
# I.2.2                1            1
# Nr.1                 1            1

# %%
# E
E_d = f"Where {s1} has no threat, but {s2} does."
E = (C[s1] == 0) & (C[s2] == 1)
print(E_d)
print('Sum: ', E.sum())
if E.sum() > 0:
    print(E)
# Out:
# Where webid-webid has no threat, but webid-didkey does.
# Sum:  0

# %%
# F
F_d = f"Where {s2} has no threat, but {s1} does."
F = (C[s2] == 0) & (C[s1] == 1)
print(F_d)
print('Sum: ', F.sum())
if F.sum() > 0:
    print(F)
# Out:
# Where webid-didkey has no threat, but webid-webid does.
# Sum:  7
# T_ID
# D.1        True
# D.2        True
# D.3        True
# DD.3.1     True
# DD.3.3     True
# I.1.1     False
# I.2.2     False
# I.2.3      True
# L.1.1      True
# Nr.1      False
# dtype: bool
