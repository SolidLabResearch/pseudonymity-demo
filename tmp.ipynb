# %%
import pandas as pd
import json
from glob import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fpaths = glob('performance-entries.*.json')
fpaths
# Out:
# ['performance-entries.SolidVCActorFactory.json',
#  'performance-entries.DidVCActorFactory.json']

# %%
dfs = pd.concat(
    dict(map(lambda x: (x.split('.')[1], pd.read_json(x)), fpaths))
    ,axis=0)
dfs.index.set_names(['factory','record_idx'],inplace=True)
dfs.reset_index(inplace=True)
display(dfs.head(3))
display(dfs.factory.value_counts())
# Out:
#                factory  record_idx  \
# 0  SolidVCActorFactory           0
# 1  SolidVCActorFactory           1
# 2  SolidVCActorFactory           2
#
#                                              name entryType    startTime  \
# 0  http://localhost:3000/alice/profile/controller  resource  2657.142250
# 1  http://localhost:3000/alice/profile/controller  resource  2708.461500
# 2  http://localhost:3000/alice/profile/controller  resource  2727.361709
#
#     duration initiatorType  workerStart  redirectStart  redirectEnd  \
# 0  50.049875         fetch          0.0            0.0          0.0
# 1  17.698375         fetch          0.0            0.0          0.0
# 2  19.986916         fetch          0.0            0.0          0.0
#
#     fetchStart  requestStart  responseStart  responseEnd  transferSize  \
# 0  2657.142250           0.0            0.0  2707.192125         300.0
# 1  2708.461500           0.0            0.0  2726.159875         300.0
# 2  2727.361709           0.0            0.0  2747.348625         300.0
#
#    encodedBodySize  decodedBodySize detail
# 0              0.0              0.0    NaN
# 1              0.0              0.0    NaN
# 2              0.0              0.0    NaN
# factory
# SolidVCActorFactory    386
# DidVCActorFactory      312
# Name: count, dtype: int64

# %% [markdown]
# **Mark type**
#
# Group `mark`-entrypTypes

# %%
dfs[dfs.entryType == 'mark'].groupby('factory').name.value_counts()
# Out:
# factory              name
# DidVCActorFactory    https://w3id.org/security/bbs/v1                                                                                                                                                                                                                                                           72
#                      https://www.w3.org/2018/credentials/v1                                                                                                                                                                                                                                                     60
#                      https://w3id.org/citizenship/v1                                                                                                                                                                                                                                                            48
#                      https://w3id.org/security/v1                                                                                                                                                                                                                                                               24
#                      https://w3id.org/security/v2                                                                                                                                                                                                                                                               24
#                      https://www.w3.org/ns/did/v1                                                                                                                                                                                                                                                               12
#                      https://w3id.org/security/suites/jws-2020/v1                                                                                                                                                                                                                                                8
#                      did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EHUQRDmVUpxUqCLQkRGMPCbTWpjsx56qHVWvvZMTg5chbYMCEKBfvxnucEEmz4RvFysZscnav2vu1PjvXo9a2ACGFWmnAku7ZD#zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EHUQRDmVUpxUqCLQkRGMPCbTWpjsx56qHVWvvZMTg5chbYMCEKBfvxnucEEmz4RvFysZscnav2vu1PjvXo9a2ACGFWmnAku7ZD     4
#                      did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EHUQRDmVUpxUqCLQkRGMPCbTWpjsx56qHVWvvZMTg5chbYMCEKBfvxnucEEmz4RvFysZscnav2vu1PjvXo9a2ACGFWmnAku7ZD                                                                                                                                             4
#                      did:key:zUC77tQFqn4247x6L3CWJpRXksGXramUDSCWHKGgvaW5w5tbbVqucJLaMhH1ZrCnisZpNLXMQrZ3WFZd44kihJRH4edVRMzWCFo2x7ZRAmSx4QWGq8wcMSUGkbFcD5T6324H8Tp#zUC77tQFqn4247x6L3CWJpRXksGXramUDSCWHKGgvaW5w5tbbVqucJLaMhH1ZrCnisZpNLXMQrZ3WFZd44kihJRH4edVRMzWCFo2x7ZRAmSx4QWGq8wcMSUGkbFcD5T6324H8Tp     2
#                      did:key:zUC77fKCxg4wS3bZUH5rfvA9ZCyVzrHoG4stZ7S5dUNeeKF7FSVwDU8xs8zFbz8WpVTJzHuJ2zzTs8WKEdP9s6TM1qenyc3XR9jmXT5eMaKpmCCW8QYdhBX7z4AiJys5fEgzcoh#zUC77fKCxg4wS3bZUH5rfvA9ZCyVzrHoG4stZ7S5dUNeeKF7FSVwDU8xs8zFbz8WpVTJzHuJ2zzTs8WKEdP9s6TM1qenyc3XR9jmXT5eMaKpmCCW8QYdhBX7z4AiJys5fEgzcoh     2
#                      start verify presentation02                                                                                                                                                                                                                                                                 1
#                      start verify presentation01                                                                                                                                                                                                                                                                 1
#                      end verify presentation02                                                                                                                                                                                                                                                                   1
#                      end verify presentation01                                                                                                                                                                                                                                                                   1
# SolidVCActorFactory  https://w3id.org/security/bbs/v1                                                                                                                                                                                                                                                           72
#                      https://www.w3.org/2018/credentials/v1                                                                                                                                                                                                                                                     60
#                      https://w3id.org/citizenship/v1                                                                                                                                                                                                                                                            48
#                      https://w3id.org/security/v2                                                                                                                                                                                                                                                               24
#                      https://w3id.org/security/v1                                                                                                                                                                                                                                                               24
#                      https://w3id.org/security/suites/jws-2020/v1                                                                                                                                                                                                                                                8
#                      http://localhost:3000/alice/profile/card#key                                                                                                                                                                                                                                                4
#                      http://localhost:3000/alice/profile/card#me                                                                                                                                                                                                                                                 4
#                      http://localhost:3003/university/profile/card#key                                                                                                                                                                                                                                           2
#                      http://localhost:3004/government/profile/card#key                                                                                                                                                                                                                                           2
#                      start verify presentation01                                                                                                                                                                                                                                                                 1
#                      end verify presentation02                                                                                                                                                                                                                                                                   1
#                      end verify presentation01                                                                                                                                                                                                                                                                   1
#                      start verify presentation02                                                                                                                                                                                                                                                                 1
# Name: count, dtype: int64

# %% [markdown]
# **RESOURCE TYPE**
# Group `resource`-entryTypes

# %%
display(dfs[dfs.entryType == 'resource'].groupby('factory').name.value_counts())
# Out:
# factory              name
# DidVCActorFactory    https://w3id.org/citizenship/v1                            24
#                      https://w3id.org/security/v1                               12
#                      https://w3id.org/security/v2                               12
# SolidVCActorFactory  https://w3id.org/citizenship/v1                            24
#                      https://w3id.org/security/v1                               12
#                      https://w3id.org/security/v2                               12
#                      http://localhost:3000/alice/profile/card                    5
#                      http://localhost:3002/recruiter/profile/card                5
#                      http://localhost:3004/government/profile/card               5
#                      http://localhost:3001/pseudo/profile/card                   5
#                      http://localhost:3003/university/profile/card               5
#                      http://localhost:3002/recruiter/profile/controller.acl      4
#                      http://localhost:3001/pseudo/profile/controller.acl         4
#                      http://localhost:3003/university/profile/controller.acl     4
#                      http://localhost:3000/alice/profile/controller.acl          4
#                      http://localhost:3004/government/profile/controller.acl     4
#                      http://localhost:3003/university/profile/controller         3
#                      http://localhost:3002/recruiter/profile/controller          3
#                      http://localhost:3001/pseudo/profile/controller             3
#                      http://localhost:3004/government/profile/controller         3
#                      http://localhost:3000/alice/profile/controller              3
#                      http://localhost:3000/alice/profile/card#me                 2
#                      http://localhost:3000/alice/profile/card#key                2
#                      http://localhost:3004/government/profile/card#key           1
#                      http://localhost:3004/government/profile/.acl               1
#                      http://localhost:3004/government/profile/                   1
#                      http://localhost:3000/alice/                                1
#                      http://localhost:3004/government/.acl                       1
#                      http://localhost:3004/government/                           1
#                      http://localhost:3003/university/profile/card#key           1
#                      http://localhost:3000/alice/profile/                        1
#                      http://localhost:3003/university/profile/.acl               1
#                      http://localhost:3003/university/profile/                   1
#                      http://localhost:3003/university/.acl                       1
#                      http://localhost:3003/university/                           1
#                      http://localhost:3000/alice/profile/.acl                    1
#                      http://localhost:3000/alice/.acl                            1
#                      http://localhost:3002/recruiter/profile/                    1
#                      http://localhost:3002/recruiter/.acl                        1
#                      http://localhost:3002/recruiter/                            1
#                      http://localhost:3001/pseudo/profile/.acl                   1
#                      http://localhost:3001/pseudo/profile/                       1
#                      http://localhost:3001/pseudo/.acl                           1
#                      http://localhost:3001/pseudo/                               1
#                      http://localhost:3002/recruiter/profile/.acl                1
# Name: count, dtype: int64

# %% [markdown]
# ---

# %%
dfs
# Out:
#                  factory  record_idx  \
# 0    SolidVCActorFactory           0
# 1    SolidVCActorFactory           1
# 2    SolidVCActorFactory           2
# 3    SolidVCActorFactory           3
# 4    SolidVCActorFactory           4
# ..                   ...         ...
# 693    DidVCActorFactory         307
# 694    DidVCActorFactory         308
# 695    DidVCActorFactory         309
# 696    DidVCActorFactory         310
# 697    DidVCActorFactory         311
#
#                                                   name entryType    startTime  \
# 0       http://localhost:3000/alice/profile/controller  resource  2657.142250
# 1       http://localhost:3000/alice/profile/controller  resource  2708.461500
# 2       http://localhost:3000/alice/profile/controller  resource  2727.361709
# 3    http://localhost:3000/alice/profile/controller...  resource  2748.256209
# 4    http://localhost:3000/alice/profile/controller...  resource  2768.579459
# ..                                                 ...       ...          ...
# 693  did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8E...      mark  8855.771125
# 694  did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8E...      mark  8856.129167
# 695                       https://www.w3.org/ns/did/v1      mark  8856.160208
# 696                       https://www.w3.org/ns/did/v1      mark  8856.163667
# 697                          end verify presentation02      mark  8856.945625
#
#       duration initiatorType  workerStart  redirectStart  redirectEnd  \
# 0    50.049875         fetch          0.0            0.0          0.0
# 1    17.698375         fetch          0.0            0.0          0.0
# 2    19.986916         fetch          0.0            0.0          0.0
# 3    19.501708         fetch          0.0            0.0          0.0
# 4    20.570916         fetch          0.0            0.0          0.0
# ..         ...           ...          ...            ...          ...
# 693   0.000000           NaN          NaN            NaN          NaN
# 694   0.000000           NaN          NaN            NaN          NaN
# 695   0.000000           NaN          NaN            NaN          NaN
# 696   0.000000           NaN          NaN            NaN          NaN
# 697   0.000000           NaN          NaN            NaN          NaN
#
#       fetchStart  requestStart  responseStart  responseEnd  transferSize  \
# 0    2657.142250           0.0            0.0  2707.192125         300.0
# 1    2708.461500           0.0            0.0  2726.159875         300.0
# 2    2727.361709           0.0            0.0  2747.348625         300.0
# 3    2748.256209           0.0            0.0  2767.757917         300.0
# 4    2768.579459           0.0            0.0  2789.150375         300.0
# ..           ...           ...            ...          ...           ...
# 693          NaN           NaN            NaN          NaN           NaN
# 694          NaN           NaN            NaN          NaN           NaN
# 695          NaN           NaN            NaN          NaN           NaN
# 696          NaN           NaN            NaN          NaN           NaN
# 697          NaN           NaN            NaN          NaN           NaN
#
#      encodedBodySize  decodedBodySize detail
# 0                0.0              0.0    NaN
# 1                0.0              0.0    NaN
# 2                0.0              0.0    NaN
# 3                0.0              0.0    NaN
# 4                0.0              0.0    NaN
# ..               ...              ...    ...
# 693              NaN              NaN  start
# 694              NaN              NaN    end
# 695              NaN              NaN  start
# 696              NaN              NaN    end
# 697              NaN              NaN   None
#
# [698 rows x 18 columns]

# %% [markdown]
# Create dataframe with only `mark` records (because Node's automatically registers performance records for each `fetch`, i.e., the records of entryType = `resource`)

# %%
dfs_marks = dfs[dfs.entryType == 'mark']
dfs_marks
# Out:
#                  factory  record_idx  \
# 80   SolidVCActorFactory          80
# 81   SolidVCActorFactory          81
# 82   SolidVCActorFactory          82
# 83   SolidVCActorFactory          83
# 84   SolidVCActorFactory          84
# ..                   ...         ...
# 693    DidVCActorFactory         307
# 694    DidVCActorFactory         308
# 695    DidVCActorFactory         309
# 696    DidVCActorFactory         310
# 697    DidVCActorFactory         311
#
#                                                   name entryType    startTime  \
# 80              https://www.w3.org/2018/credentials/v1      mark  8028.325750
# 81              https://www.w3.org/2018/credentials/v1      mark  8028.449292
# 82                    https://w3id.org/security/bbs/v1      mark  8028.774459
# 83                    https://w3id.org/security/bbs/v1      mark  8028.780334
# 84                     https://w3id.org/citizenship/v1      mark  8028.831875
# ..                                                 ...       ...          ...
# 693  did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8E...      mark  8855.771125
# 694  did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8E...      mark  8856.129167
# 695                       https://www.w3.org/ns/did/v1      mark  8856.160208
# 696                       https://www.w3.org/ns/did/v1      mark  8856.163667
# 697                          end verify presentation02      mark  8856.945625
#
#      duration initiatorType  workerStart  redirectStart  redirectEnd  \
# 80        0.0           NaN          NaN            NaN          NaN
# 81        0.0           NaN          NaN            NaN          NaN
# 82        0.0           NaN          NaN            NaN          NaN
# 83        0.0           NaN          NaN            NaN          NaN
# 84        0.0           NaN          NaN            NaN          NaN
# ..        ...           ...          ...            ...          ...
# 693       0.0           NaN          NaN            NaN          NaN
# 694       0.0           NaN          NaN            NaN          NaN
# 695       0.0           NaN          NaN            NaN          NaN
# 696       0.0           NaN          NaN            NaN          NaN
# 697       0.0           NaN          NaN            NaN          NaN
#
#      fetchStart  requestStart  responseStart  responseEnd  transferSize  \
# 80          NaN           NaN            NaN          NaN           NaN
# 81          NaN           NaN            NaN          NaN           NaN
# 82          NaN           NaN            NaN          NaN           NaN
# 83          NaN           NaN            NaN          NaN           NaN
# 84          NaN           NaN            NaN          NaN           NaN
# ..          ...           ...            ...          ...           ...
# 693         NaN           NaN            NaN          NaN           NaN
# 694         NaN           NaN            NaN          NaN           NaN
# 695         NaN           NaN            NaN          NaN           NaN
# 696         NaN           NaN            NaN          NaN           NaN
# 697         NaN           NaN            NaN          NaN           NaN
#
#      encodedBodySize  decodedBodySize detail
# 80               NaN              NaN  start
# 81               NaN              NaN    end
# 82               NaN              NaN  start
# 83               NaN              NaN    end
# 84               NaN              NaN  start
# ..               ...              ...    ...
# 693              NaN              NaN  start
# 694              NaN              NaN    end
# 695              NaN              NaN  start
# 696              NaN              NaN    end
# 697              NaN              NaN   None
#
# [516 rows x 18 columns]

# %% [markdown]
# Obtain the record indices that mark the start and end of *verify presentation*, so we can consider only the performance records registered during that period).

# %%
verify_dataframes = {}
for x in ['presentation01','presentation02']:
    a = f'start verify {x}'
    b = f'end verify {x}'
    idx_start = dfs[dfs.name.str.contains(a)].set_index('factory').record_idx.to_dict()
    idx_end = dfs[dfs.name.str.contains(b)].set_index('factory').record_idx.to_dict()
    fac_df_verify = {}
    for fac in ['DidVCActorFactory', 'SolidVCActorFactory']:
        
        i0,i1 = idx_start[fac], idx_end[fac]
        assert i0 < i1
        fac_df_verify[fac] = dfs_marks.set_index(['factory','record_idx'])\
            .loc[fac]\
            .loc[i0+1:i1-1] # the slice between start & verify presentation (excluding the records that mark the start and verify presentation records)
    df_verify = pd.concat(fac_df_verify,names=['factory'])
    df_verify.dropna(how='all',axis=1,inplace=True) # clean up nan columns
    df_verify = df_verify.reset_index().sort_values(['startTime'],ascending=[True])
    # Compute a pair-wise incremental group index (this will allow us to unstack on the column detail, to obtain one row that contains the start and end startTimes)
    df_verify['group_idx'] =  df_verify.groupby(['factory']).cumcount() // 2
    df_verify.reset_index(inplace=True)
    # Unstack by detail so that each row contains the start and end times
    df_verify_unstacked = df_verify.set_index(['factory','name','detail','group_idx']).startTime.unstack('detail').sort_values('start')
    df_verify_unstacked['duration'] = df_verify_unstacked.end - df_verify_unstacked.start
    verify_dataframes[x] = df_verify_unstacked

# %%
dfs_v = pd.concat(verify_dataframes, names=['presentation'])
dfs_v
# Out:
# detail                                                                                                    end  \
# presentation   factory             name                                               group_idx
# presentation01 DidVCActorFactory   https://www.w3.org/2018/credentials/v1             0           5483.182083
#                                    https://w3id.org/security/bbs/v1                   1           5483.294417
#                                    https://w3id.org/citizenship/v1                    2           5619.080333
#                                    https://w3id.org/security/suites/jws-2020/v1       3           5625.077500
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 4           5625.464667
#                                    https://www.w3.org/ns/did/v1                       5           5625.488542
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 6           5638.896000
#                                    https://www.w3.org/ns/did/v1                       7           5638.946708
#                SolidVCActorFactory https://www.w3.org/2018/credentials/v1             0          11687.528667
#                                    https://w3id.org/security/bbs/v1                   1          11687.629417
#                                    https://w3id.org/citizenship/v1                    2          11831.581417
#                                    https://w3id.org/security/suites/jws-2020/v1       3          11840.612459
#                                    http://localhost:3000/alice/profile/card#key       4          11902.771917
#                                    http://localhost:3000/alice/profile/card#me        5          11958.286084
# presentation02 DidVCActorFactory   https://www.w3.org/2018/credentials/v1             0           8714.267000
#                                    https://w3id.org/security/bbs/v1                   1           8714.325708
#                                    https://w3id.org/citizenship/v1                    2           8821.396833
#                                    https://w3id.org/security/suites/jws-2020/v1       3           8833.033458
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 4           8833.632958
#                                    https://www.w3.org/ns/did/v1                       5           8833.672667
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 6           8856.129167
#                                    https://www.w3.org/ns/did/v1                       7           8856.163667
#                SolidVCActorFactory https://www.w3.org/2018/credentials/v1             0          15127.906792
#                                    https://w3id.org/security/bbs/v1                   1          15127.962584
#                                    https://w3id.org/citizenship/v1                    2          15236.935292
#                                    https://w3id.org/security/suites/jws-2020/v1       3          15258.137084
#                                    http://localhost:3000/alice/profile/card#key       4          15307.712125
#                                    http://localhost:3000/alice/profile/card#me        5          15362.223834
#
# detail                                                                                                  start  \
# presentation   factory             name                                               group_idx
# presentation01 DidVCActorFactory   https://www.w3.org/2018/credentials/v1             0           5483.173583
#                                    https://w3id.org/security/bbs/v1                   1           5483.290208
#                                    https://w3id.org/citizenship/v1                    2           5484.189125
#                                    https://w3id.org/security/suites/jws-2020/v1       3           5625.061750
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 4           5625.120333
#                                    https://www.w3.org/ns/did/v1                       5           5625.485792
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 6           5638.312542
#                                    https://www.w3.org/ns/did/v1                       7           5638.941958
#                SolidVCActorFactory https://www.w3.org/2018/credentials/v1             0          11687.520000
#                                    https://w3id.org/security/bbs/v1                   1          11687.625709
#                                    https://w3id.org/citizenship/v1                    2          11688.409875
#                                    https://w3id.org/security/suites/jws-2020/v1       3          11840.594292
#                                    http://localhost:3000/alice/profile/card#key       4          11840.675709
#                                    http://localhost:3000/alice/profile/card#me        5          11928.599792
# presentation02 DidVCActorFactory   https://www.w3.org/2018/credentials/v1             0           8714.254000
#                                    https://w3id.org/security/bbs/v1                   1           8714.322750
#                                    https://w3id.org/citizenship/v1                    2           8714.804083
#                                    https://w3id.org/security/suites/jws-2020/v1       3           8833.006792
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 4           8833.099542
#                                    https://www.w3.org/ns/did/v1                       5           8833.666083
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 6           8855.771125
#                                    https://www.w3.org/ns/did/v1                       7           8856.160208
#                SolidVCActorFactory https://www.w3.org/2018/credentials/v1             0          15127.901917
#                                    https://w3id.org/security/bbs/v1                   1          15127.960417
#                                    https://w3id.org/citizenship/v1                    2          15128.365250
#                                    https://w3id.org/security/suites/jws-2020/v1       3          15258.096292
#                                    http://localhost:3000/alice/profile/card#key       4          15258.379209
#                                    http://localhost:3000/alice/profile/card#me        5          15340.715125
#
# detail                                                                                             duration
# presentation   factory             name                                               group_idx
# presentation01 DidVCActorFactory   https://www.w3.org/2018/credentials/v1             0            0.008500
#                                    https://w3id.org/security/bbs/v1                   1            0.004209
#                                    https://w3id.org/citizenship/v1                    2          134.891208
#                                    https://w3id.org/security/suites/jws-2020/v1       3            0.015750
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 4            0.344334
#                                    https://www.w3.org/ns/did/v1                       5            0.002750
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 6            0.583458
#                                    https://www.w3.org/ns/did/v1                       7            0.004750
#                SolidVCActorFactory https://www.w3.org/2018/credentials/v1             0            0.008667
#                                    https://w3id.org/security/bbs/v1                   1            0.003708
#                                    https://w3id.org/citizenship/v1                    2          143.171542
#                                    https://w3id.org/security/suites/jws-2020/v1       3            0.018167
#                                    http://localhost:3000/alice/profile/card#key       4           62.096208
#                                    http://localhost:3000/alice/profile/card#me        5           29.686292
# presentation02 DidVCActorFactory   https://www.w3.org/2018/credentials/v1             0            0.013000
#                                    https://w3id.org/security/bbs/v1                   1            0.002958
#                                    https://w3id.org/citizenship/v1                    2          106.592750
#                                    https://w3id.org/security/suites/jws-2020/v1       3            0.026666
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 4            0.533416
#                                    https://www.w3.org/ns/did/v1                       5            0.006584
#                                    did:key:zUC79nD3kTq71aFonkDrcbR1UuN8ZD7Txy4X8EH... 6            0.358042
#                                    https://www.w3.org/ns/did/v1                       7            0.003459
#                SolidVCActorFactory https://www.w3.org/2018/credentials/v1             0            0.004875
#                                    https://w3id.org/security/bbs/v1                   1            0.002167
#                                    https://w3id.org/citizenship/v1                    2          108.570042
#                                    https://w3id.org/security/suites/jws-2020/v1       3            0.040792
#                                    http://localhost:3000/alice/profile/card#key       4           49.332916
#                                    http://localhost:3000/alice/profile/card#me        5           21.508709

# %%
dfs_v.reset_index().groupby(['presentation','factory']).duration.sum()
# Out:
# presentation    factory
# presentation01  DidVCActorFactory      135.854959
#                 SolidVCActorFactory    234.984584
# presentation02  DidVCActorFactory      107.536875
#                 SolidVCActorFactory    179.459501
# Name: duration, dtype: float64

# %%
dfs_v.to_excel('dfs_v_performance_marks_agg-preload-did-v1-context.xlsx')

# %% [markdown]
# ---

# %% [raw]
# # meta: verify-presentation-01 contains performance records registered while executing verify presentation 01
# # (as part of the diploma verification phase) by two different implementations (i.e., SolidVCActor vs. DidVCActor, as denoted by the factory)
#
# df_verify_unstacked.to_excel('df_verify_presentation01_performance_marks.xlsx')
